# %%
# Table 31: Summary of Pareto-Front analysis on kroD100.tsp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Create a DataFrame from the data
data = {
    'Cost': [1484660.057897728, 1442677.7406094524, 1433045.9324615097, 1397849.345850042, 1442224.6100796172, 1449408.816266233, 1360933.9760535618, 1404554.8106816416, 1426302.7495149265, 1420246.1458948313],
    'Time': [0.1233069101969401, 0.12593348821004233, 0.5328218142191569, 0.5270870526631674, 0.31752069791158044, 0.2073546250661214, 0.660637617111206, 2.3483526706695557, 0.7320070266723633, 0.2887304623921712]
}

df = pd.DataFrame(data)

# Adjust index to start from 1 instead of 0
df.index = df.index + 1

# Plot Pareto front
cost = np.array(df['Cost'])
time = np.array(df['Time'])

plt.scatter(cost, time, label='Solutions')
plt.xlabel('Cost')
plt.ylabel('Time')
plt.title('Pareto Front')

# Identify Pareto front
def pareto_front(cost, time):
    # Normalize cost and time to the same scale
    normalized_cost = (cost - np.min(cost)) / (np.max(cost) - np.min(cost))
    normalized_time = (time - np.min(time)) / (np.max(time) - np.min(time))

    # Calculate the composite score as the sum of normalized cost and time
    composite_score = normalized_cost + normalized_time

    # Find the index of the solution with the lowest composite score
    optimal_index = np.argmin(composite_score)

    # Create a boolean array that is True only for the optimal solution
    is_pareto = np.zeros(cost.shape[0], dtype=bool)
    is_pareto[optimal_index] = True

    return is_pareto

pareto = pareto_front(cost, time)
plt.scatter(cost[pareto], time[pareto], color='red', label='Optimal Solution')
plt.legend()
plt.show()

# Print the details of the optimal solution
optimal_solution = df.iloc[np.where(pareto)]
print("Optimal Solution:")
print(optimal_solution)

sorted_cost_indices = np.argsort(cost)
sorted_time_indices = np.argsort(time)

optimal_cost_place = np.where(sorted_cost_indices == optimal_solution.index[0]-1)[0][0] + 1
optimal_time_place = np.where(sorted_time_indices == optimal_solution.index[0]-1)[0][0] + 1

print(f"Cost place: {optimal_cost_place}")
print(f"Time place: {optimal_time_place}")
# Out:
# Optimal Solution:
#            Cost      Time
# 7  1.360934e+06  0.660638
# Cost place: 1
# Time place: 8

# %%
# Table 31: Summary of Pareto-Front analysis on st70.tsp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Create a DataFrame from the data
data = {
    'Cost': [31948.952732592617, 32752.31947653416, 30252.972756940417, 31440.926343067007, 32746.175653656268, 30716.612294238857, 31554.285992346187, 30571.54440415776, 31161.413866654602, 31172.003762081113],
    'Time': [0.38399060567220056, 0.10055979092915854, 0.48059701919555664, 0.30052383740743, 0.3529783089955648, 0.12979586919148764, 0.4603521029154459, 1.1059296131134033, 0.48948208491007483, 0.23583014806111652]
}

df = pd.DataFrame(data)

# Adjust index to start from 1 instead of 0
df.index = df.index + 1

# Plot Pareto front
cost = np.array(df['Cost'])
time = np.array(df['Time'])

plt.scatter(cost, time, label='Solutions')
plt.xlabel('Cost')
plt.ylabel('Time')
plt.title('Pareto Front')

# Identify Pareto front
def pareto_front(cost, time):
    # Normalize cost and time to the same scale
    normalized_cost = (cost - np.min(cost)) / (np.max(cost) - np.min(cost))
    normalized_time = (time - np.min(time)) / (np.max(time) - np.min(time))

    # Calculate the composite score as the sum of normalized cost and time
    composite_score = normalized_cost + normalized_time

    # Find the index of the solution with the lowest composite score
    optimal_index = np.argmin(composite_score)

    # Create a boolean array that is True only for the optimal solution
    is_pareto = np.zeros(cost.shape[0], dtype=bool)
    is_pareto[optimal_index] = True

    return is_pareto

pareto = pareto_front(cost, time)
plt.scatter(cost[pareto], time[pareto], color='red', label='Optimal Solution')
plt.legend()
plt.show()

# Print the details of the optimal solution
optimal_solution = df.iloc[np.where(pareto)]
print("Optimal Solution:")
print(optimal_solution)

sorted_cost_indices = np.argsort(cost)
sorted_time_indices = np.argsort(time)

optimal_cost_place = np.where(sorted_cost_indices == optimal_solution.index[0]-1)[0][0] + 1
optimal_time_place = np.where(sorted_time_indices == optimal_solution.index[0]-1)[0][0] + 1

print(f"Cost place: {optimal_cost_place}")
print(f"Time place: {optimal_time_place}")
# Out:
# Optimal Solution:
#            Cost      Time
# 6  30716.612294  0.129796
# Cost place: 3
# Time place: 2

# %%
# Table 31: Summary of Pareto-Front analysis on rat99.tsp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Create a DataFrame from the data
data = {
    'Cost': [74347.26885502602, 72975.19790192926, 72527.31672293489, 73126.75088642482, 71106.58161416487, 74483.62771663794, 71112.0901964305, 71980.16657768041, 70467.7436518865, 70894.60521054444],
    'Time': [0.11778791745503744, 0.12704849243164062, 0.6409533818562825, 0.41603406270345056, 0.3191634019215902, 0.17235398292541504, 0.8292663097381592, 2.027860482533773, 1.0010552406311035, 0.2879134813944499]
}

df = pd.DataFrame(data)

# Adjust index to start from 1 instead of 0
df.index = df.index + 1

# Plot Pareto front
cost = np.array(df['Cost'])
time = np.array(df['Time'])

plt.scatter(cost, time, label='Solutions')
plt.xlabel('Cost')
plt.ylabel('Time')
plt.title('Pareto Front')

# Identify Pareto front
def pareto_front(cost, time):
    # Normalize cost and time to the same scale
    normalized_cost = (cost - np.min(cost)) / (np.max(cost) - np.min(cost))
    normalized_time = (time - np.min(time)) / (np.max(time) - np.min(time))

    # Calculate the composite score as the sum of normalized cost and time
    composite_score = normalized_cost + normalized_time

    # Find the index of the solution with the lowest composite score
    optimal_index = np.argmin(composite_score)

    # Create a boolean array that is True only for the optimal solution
    is_pareto = np.zeros(cost.shape[0], dtype=bool)
    is_pareto[optimal_index] = True

    return is_pareto

pareto = pareto_front(cost, time)
plt.scatter(cost[pareto], time[pareto], color='red', label='Optimal Solution')
plt.legend()
plt.show()

# Print the details of the optimal solution
optimal_solution = df.iloc[np.where(pareto)]
print("Optimal Solution:")
print(optimal_solution)

sorted_cost_indices = np.argsort(cost)
sorted_time_indices = np.argsort(time)

optimal_cost_place = np.where(sorted_cost_indices == optimal_solution.index[0]-1)[0][0] + 1
optimal_time_place = np.where(sorted_time_indices == optimal_solution.index[0]-1)[0][0] + 1

print(f"Cost place: {optimal_cost_place}")
print(f"Time place: {optimal_time_place}")
# Out:
# Optimal Solution:
#             Cost      Time
# 10  70894.605211  0.287913
# Cost place: 2
# Time place: 4

# %%
# Table 31: Summary of Pareto-Front analysis on lin105.tsp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Create a DataFrame from the data
data = {
    'Cost': [1089820.3012261835, 1074455.348194267, 1066455.7941437399, 1046500.5526384687, 1035214.5986038991, 1072564.5047442694, 1072460.7739388212, 1045773.2887059847, 1056006.7447181193, 1038753.4810851652],
    'Time': [0.17111897468566895, 0.21255532900492352, 0.6938735644022624, 0.6789700190226238, 0.3371969858805338, 0.1943846543629964, 0.6092480818430582, 1.4850703875223794, 0.75661301612854, 0.5465002854665121]
}

df = pd.DataFrame(data)

# Adjust index to start from 1 instead of 0
df.index = df.index + 1

# Plot Pareto front
cost = np.array(df['Cost'])
time = np.array(df['Time'])

plt.scatter(cost, time, label='Solutions')
plt.xlabel('Cost')
plt.ylabel('Time')
plt.title('Pareto Front')

# Identify Pareto front
def pareto_front(cost, time):
    # Normalize cost and time to the same scale
    normalized_cost = (cost - np.min(cost)) / (np.max(cost) - np.min(cost))
    normalized_time = (time - np.min(time)) / (np.max(time) - np.min(time))

    # Calculate the composite score as the sum of normalized cost and time
    composite_score = normalized_cost + normalized_time

    # Find the index of the solution with the lowest composite score
    optimal_index = np.argmin(composite_score)

    # Create a boolean array that is True only for the optimal solution
    is_pareto = np.zeros(cost.shape[0], dtype=bool)
    is_pareto[optimal_index] = True

    return is_pareto

pareto = pareto_front(cost, time)
plt.scatter(cost[pareto], time[pareto], color='red', label='Optimal Solution')
plt.legend()
plt.show()

# Print the details of the optimal solution
optimal_solution = df.iloc[np.where(pareto)]
print("Optimal Solution:")
print(optimal_solution)

sorted_cost_indices = np.argsort(cost)
sorted_time_indices = np.argsort(time)

optimal_cost_place = np.where(sorted_cost_indices == optimal_solution.index[0]-1)[0][0] + 1
optimal_time_place = np.where(sorted_time_indices == optimal_solution.index[0]-1)[0][0] + 1

print(f"Cost place: {optimal_cost_place}")
print(f"Time place: {optimal_time_place}")
# Out:
# Optimal Solution:
#            Cost      Time
# 5  1.035215e+06  0.337197
# Cost place: 1
# Time place: 4

# %%
# Table 31: Summary of Pareto-Front analysis on pr107.tsp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Create a DataFrame from the data
data = {
    'Cost': [4893166.543687696, 5025053.54975736, 4762145.915993273, 5033514.106489745, 4607942.815421155, 5034073.756655916, 4889139.291363021, 5005127.480007265, 4567830.287216031, 4850656.479173713],
    'Time': [0.16974012056986493, 0.11144042015075684, 0.6287062168121338, 0.44584552447001136, 0.26645978291829425, 0.15950759251912433, 0.5819900830586752, 1.1988770961761475, 0.66122571627299, 0.28408368428548175]
}

df = pd.DataFrame(data)

# Adjust index to start from 1 instead of 0
df.index = df.index + 1

# Plot Pareto front
cost = np.array(df['Cost'])
time = np.array(df['Time'])

plt.scatter(cost, time, label='Solutions')
plt.xlabel('Cost')
plt.ylabel('Time')
plt.title('Pareto Front')

# Identify Pareto front
def pareto_front(cost, time):
    # Normalize cost and time to the same scale
    normalized_cost = (cost - np.min(cost)) / (np.max(cost) - np.min(cost))
    normalized_time = (time - np.min(time)) / (np.max(time) - np.min(time))

    # Calculate the composite score as the sum of normalized cost and time
    composite_score = normalized_cost + normalized_time

    # Find the index of the solution with the lowest composite score
    optimal_index = np.argmin(composite_score)

    # Create a boolean array that is True only for the optimal solution
    is_pareto = np.zeros(cost.shape[0], dtype=bool)
    is_pareto[optimal_index] = True

    return is_pareto

pareto = pareto_front(cost, time)
plt.scatter(cost[pareto], time[pareto], color='red', label='Optimal Solution')
plt.legend()
plt.show()

# Print the details of the optimal solution
optimal_solution = df.iloc[np.where(pareto)]
print("Optimal Solution:")
print(optimal_solution)

sorted_cost_indices = np.argsort(cost)
sorted_time_indices = np.argsort(time)

optimal_cost_place = np.where(sorted_cost_indices == optimal_solution.index[0]-1)[0][0] + 1
optimal_time_place = np.where(sorted_time_indices == optimal_solution.index[0]-1)[0][0] + 1

print(f"Cost place: {optimal_cost_place}")
print(f"Time place: {optimal_time_place}")
# Out:
# Optimal Solution:
#            Cost     Time
# 5  4.607943e+06  0.26646
# Cost place: 2
# Time place: 4

# %%
# Table 31: Summary of Pareto-Front analysis on rat195.tsp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Create a DataFrame from the data
data = {
    'Cost': [207914.28926830395, 206263.64839601546, 198983.90161682852, 204602.35798599262, 205171.87934373625, 210664.18878334065, 209370.88991108997, 208890.17781840407, 199978.18765018787, 201079.13440530852],
    'Time': [0.19981106122334796, 0.23153106371561688, 1.033632755279541, 1.13724152247111, 0.6723809242248535, 0.29856165250142414, 1.0900906721750896, 2.929362456003825, 1.4088678359985352, 0.6010882059733073]
}

df = pd.DataFrame(data)

# Adjust index to start from 1 instead of 0
df.index = df.index + 1

# Plot Pareto front
cost = np.array(df['Cost'])
time = np.array(df['Time'])

plt.scatter(cost, time, label='Solutions')
plt.xlabel('Cost')
plt.ylabel('Time')
plt.title('Pareto Front')

# Identify Pareto front
def pareto_front(cost, time):
    # Normalize cost and time to the same scale
    normalized_cost = (cost - np.min(cost)) / (np.max(cost) - np.min(cost))
    normalized_time = (time - np.min(time)) / (np.max(time) - np.min(time))

    # Calculate the composite score as the sum of normalized cost and time
    composite_score = normalized_cost + normalized_time

    # Find the index of the solution with the lowest composite score
    optimal_index = np.argmin(composite_score)

    # Create a boolean array that is True only for the optimal solution
    is_pareto = np.zeros(cost.shape[0], dtype=bool)
    is_pareto[optimal_index] = True

    return is_pareto

pareto = pareto_front(cost, time)
plt.scatter(cost[pareto], time[pareto], color='red', label='Optimal Solution')
plt.legend()
plt.show()

# Print the details of the optimal solution
optimal_solution = df.iloc[np.where(pareto)]
print("Optimal Solution:")
print(optimal_solution)

sorted_cost_indices = np.argsort(cost)
sorted_time_indices = np.argsort(time)

optimal_cost_place = np.where(sorted_cost_indices == optimal_solution.index[0]-1)[0][0] + 1
optimal_time_place = np.where(sorted_time_indices == optimal_solution.index[0]-1)[0][0] + 1

print(f"Cost place: {optimal_cost_place}")
print(f"Time place: {optimal_time_place}")
# Out:
# Optimal Solution:
#             Cost      Time
# 3  198983.901617  1.033633
# Cost place: 1
# Time place: 6

# %%
# Table 31: Summary of Pareto-Front analysis on pr226.tsp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Create a DataFrame from the data
data = {
    'Cost': [15364428.6613202, 15651558.16312206, 15168567.543992253, 15597533.103234049, 15190161.291651642, 15509257.354074253, 15510553.01507824, 15293888.451824293, 15153980.616271183, 15304621.77344559],
    'Time': [0.24309714635213214, 0.24840474128723145, 1.1300937334696453, 1.48530642191569, 0.5737547079722086, 0.33765077590942383, 1.9308308760325112, 3.02728811899821, 2.3123780886332193, 0.630703369776408]
}

df = pd.DataFrame(data)

# Adjust index to start from 1 instead of 0
df.index = df.index + 1

# Plot Pareto front
cost = np.array(df['Cost'])
time = np.array(df['Time'])

plt.scatter(cost, time, label='Solutions')
plt.xlabel('Cost')
plt.ylabel('Time')
plt.title('Pareto Front')

# Identify Pareto front
def pareto_front(cost, time):
    # Normalize cost and time to the same scale
    normalized_cost = (cost - np.min(cost)) / (np.max(cost) - np.min(cost))
    normalized_time = (time - np.min(time)) / (np.max(time) - np.min(time))

    # Calculate the composite score as the sum of normalized cost and time
    composite_score = normalized_cost + normalized_time

    # Find the index of the solution with the lowest composite score
    optimal_index = np.argmin(composite_score)

    # Create a boolean array that is True only for the optimal solution
    is_pareto = np.zeros(cost.shape[0], dtype=bool)
    is_pareto[optimal_index] = True

    return is_pareto

pareto = pareto_front(cost, time)
plt.scatter(cost[pareto], time[pareto], color='red', label='Optimal Solution')
plt.legend()
plt.show()

# Print the details of the optimal solution
optimal_solution = df.iloc[np.where(pareto)]
print("Optimal Solution:")
print(optimal_solution)

sorted_cost_indices = np.argsort(cost)
sorted_time_indices = np.argsort(time)

optimal_cost_place = np.where(sorted_cost_indices == optimal_solution.index[0]-1)[0][0] + 1
optimal_time_place = np.where(sorted_time_indices == optimal_solution.index[0]-1)[0][0] + 1

print(f"Cost place: {optimal_cost_place}")
print(f"Time place: {optimal_time_place}")
# Out:
# Optimal Solution:
#            Cost      Time
# 5  1.519016e+07  0.573755
# Cost place: 3
# Time place: 4

# %%
# Table 31: Summary of Pareto-Front analysis on lin318.tsp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Create a DataFrame from the data
data = {
    'Cost': [5583913.561074291, 5431775.4661265025, 5466115.264886856, 5468574.860855648, 5569810.37861986, 5432817.692123719, 5466100.722576515, 5547653.108661576, 5468935.970645202, 5504025.979274563],
    'Time': [0.4075205326080322, 0.35671631495157874, 1.6742869218190513, 1.2464344501495361, 0.8401282628377278, 0.5041114489237467, 1.6689328352610269, 7.1541547775268555, 1.9893666108449302, 0.90667724609375]
}

df = pd.DataFrame(data)

# Adjust index to start from 1 instead of 0
df.index = df.index + 1

# Plot Pareto front
cost = np.array(df['Cost'])
time = np.array(df['Time'])

plt.scatter(cost, time, label='Solutions')
plt.xlabel('Cost')
plt.ylabel('Time')
plt.title('Pareto Front')

# Identify Pareto front
def pareto_front(cost, time):
    # Normalize cost and time to the same scale
    normalized_cost = (cost - np.min(cost)) / (np.max(cost) - np.min(cost))
    normalized_time = (time - np.min(time)) / (np.max(time) - np.min(time))

    # Calculate the composite score as the sum of normalized cost and time
    composite_score = normalized_cost + normalized_time

    # Find the index of the solution with the lowest composite score
    optimal_index = np.argmin(composite_score)

    # Create a boolean array that is True only for the optimal solution
    is_pareto = np.zeros(cost.shape[0], dtype=bool)
    is_pareto[optimal_index] = True

    return is_pareto

pareto = pareto_front(cost, time)
plt.scatter(cost[pareto], time[pareto], color='red', label='Optimal Solution')
plt.legend()
plt.show()

# Print the details of the optimal solution
optimal_solution = df.iloc[np.where(pareto)]
print("Optimal Solution:")
print(optimal_solution)

sorted_cost_indices = np.argsort(cost)
sorted_time_indices = np.argsort(time)

optimal_cost_place = np.where(sorted_cost_indices == optimal_solution.index[0]-1)[0][0] + 1
optimal_time_place = np.where(sorted_time_indices == optimal_solution.index[0]-1)[0][0] + 1

print(f"Cost place: {optimal_cost_place}")
print(f"Time place: {optimal_time_place}")
# Out:
# Optimal Solution:
#            Cost      Time
# 2  5.431775e+06  0.356716
# Cost place: 1
# Time place: 1

# %%
# Table 31: Summary of Pareto-Front analysis on pr439.tsp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Create a DataFrame from the data
data = {
    'Cost': [18108662.99306692, 18244068.391059708, 17702575.85108042, 17691909.05949979, 17924930.61937383, 18033651.61515136, 17507932.556428384, 17968888.777402207, 17685965.095425382, 17645916.986069392],
    'Time': [0.8150708675384521, 0.8503293991088867, 2.2486714522043862, 1.691624323527018, 2.0508197943369546, 0.685182015101115, 2.4119714895884194, 6.9895195960998535, 2.9686061541239424, 1.4854697386423745]
}

df = pd.DataFrame(data)

# Adjust index to start from 1 instead of 0
df.index = df.index + 1

# Plot Pareto front
cost = np.array(df['Cost'])
time = np.array(df['Time'])

plt.scatter(cost, time, label='Solutions')
plt.xlabel('Cost')
plt.ylabel('Time')
plt.title('Pareto Front')

# Identify Pareto front
def pareto_front(cost, time):
    # Normalize cost and time to the same scale
    normalized_cost = (cost - np.min(cost)) / (np.max(cost) - np.min(cost))
    normalized_time = (time - np.min(time)) / (np.max(time) - np.min(time))

    # Calculate the composite score as the sum of normalized cost and time
    composite_score = normalized_cost + normalized_time

    # Find the index of the solution with the lowest composite score
    optimal_index = np.argmin(composite_score)

    # Create a boolean array that is True only for the optimal solution
    is_pareto = np.zeros(cost.shape[0], dtype=bool)
    is_pareto[optimal_index] = True

    return is_pareto

pareto = pareto_front(cost, time)
plt.scatter(cost[pareto], time[pareto], color='red', label='Optimal Solution')
plt.legend()
plt.show()

# Print the details of the optimal solution
optimal_solution = df.iloc[np.where(pareto)]
print("Optimal Solution:")
print(optimal_solution)

sorted_cost_indices = np.argsort(cost)
sorted_time_indices = np.argsort(time)

optimal_cost_place = np.where(sorted_cost_indices == optimal_solution.index[0]-1)[0][0] + 1
optimal_time_place = np.where(sorted_time_indices == optimal_solution.index[0]-1)[0][0] + 1

print(f"Cost place: {optimal_cost_place}")
print(f"Time place: {optimal_time_place}")
# Out:
# Optimal Solution:
#            Cost      Time
# 7  1.750793e+07  2.411971
# Cost place: 1
# Time place: 8
